# %%
import json
import ROOT
# Out:
# Welcome to JupyROOT 6.30/02

# %%
file=ROOT.TFile("reco_standard_mu-_1930_-200_0.root","READ")
events=file.Events
events.Print()
# Out:
# ******************************************************************************
# *Tree    :Events    : Tree Created by SimAna                                 *
# *Entries :     1000 : Total =         5819926 bytes  File  Size =    1230645 *
# *        :          : Tree compression factor =   4.67                       *
# ******************************************************************************
# *Br    0 :eventID   : eventID/I                                              *
# *Entries :     1000 : Total  Size=       4569 bytes  File Size  =       1520 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.68     *
# *............................................................................*
# *Br    1 :totalTime : totalTime/F                                            *
# *Entries :     1000 : Total  Size=       4579 bytes  File Size  =       3668 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.11     *
# *............................................................................*
# *Br    2 :allRecoed : allRecoed/I                                            *
# *Entries :     1000 : Total  Size=       4579 bytes  File Size  =        541 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   7.54     *
# *............................................................................*
# *Br    3 :allCouldBeRecoed : allCouldBeRecoed/I                              *
# *Entries :     1000 : Total  Size=       4614 bytes  File Size  =        465 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   8.78     *
# *............................................................................*
# *Br    4 :numNonMatched : numNonMatched/I                                    *
# *Entries :     1000 : Total  Size=       4599 bytes  File Size  =        132 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  30.92     *
# *............................................................................*
# *Br    5 :nTrueDM   : nTrueDM/I                                              *
# *Entries :     1000 : Total  Size=       4569 bytes  File Size  =        126 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  32.35     *
# *............................................................................*
# *Br    6 :nFakeDM   : nFakeDM/I                                              *
# *Entries :     1000 : Total  Size=       4569 bytes  File Size  =        126 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  32.35     *
# *............................................................................*
# *Br    7 :nFakeTracksTop2 : nFakeTracksTop2/I                                *
# *Entries :     1000 : Total  Size=       4609 bytes  File Size  =        134 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  30.48     *
# *............................................................................*
# *Br    8 :nRealTracks : nRealTracks/I                                        *
# *Entries :     1000 : Total  Size=       4589 bytes  File Size  =        543 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   7.51     *
# *............................................................................*
# *Br    9 :mainDMRecoed : mainDMRecoed/I                                      *
# *Entries :     1000 : Total  Size=       4594 bytes  File Size  =        131 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  31.15     *
# *............................................................................*
# *Br   10 :passHitCuts : passHitCuts/I                                        *
# *Entries :     1000 : Total  Size=       4589 bytes  File Size  =        135 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  30.22     *
# *............................................................................*
# *Br   11 :n_hits    : n_hits/I                                               *
# *Entries :     1000 : Total  Size=       4564 bytes  File Size  =       1126 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   3.62     *
# *............................................................................*
# *Br   12 :n_hits_h1x : n_hits_h1x/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        378 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  10.79     *
# *............................................................................*
# *Br   13 :n_hits_h2x : n_hits_h2x/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        544 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   7.50     *
# *............................................................................*
# *Br   14 :n_hits_h3x : n_hits_h3x/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        549 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   7.43     *
# *............................................................................*
# *Br   15 :n_hits_h4x : n_hits_h4x/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        552 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   7.39     *
# *............................................................................*
# *Br   16 :n_hits_d0x : n_hits_d0x/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        357 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  11.43     *
# *............................................................................*
# *Br   17 :n_hits_d2x : n_hits_d2x/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        449 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   9.08     *
# *............................................................................*
# *Br   18 :n_hits_d3px : n_hits_d3px/I                                        *
# *Entries :     1000 : Total  Size=       4589 bytes  File Size  =        554 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   7.36     *
# *............................................................................*
# *Br   19 :n_hits_d3mx : n_hits_d3mx/I                                        *
# *Entries :     1000 : Total  Size=       4589 bytes  File Size  =        556 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   7.34     *
# *............................................................................*
# *Br   20 :n_hits_d0 : n_hits_d0/I                                            *
# *Entries :     1000 : Total  Size=       4579 bytes  File Size  =        408 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  10.00     *
# *............................................................................*
# *Br   21 :n_hits_d1 : n_hits_d1/I                                            *
# *Entries :     1000 : Total  Size=       4579 bytes  File Size  =        128 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  31.86     *
# *............................................................................*
# *Br   22 :n_hits_d2 : n_hits_d2/I                                            *
# *Entries :     1000 : Total  Size=       4579 bytes  File Size  =        486 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   8.39     *
# *............................................................................*
# *Br   23 :n_hits_d3p : n_hits_d3p/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        614 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   6.64     *
# *............................................................................*
# *Br   24 :n_hits_d3m : n_hits_d3m/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        607 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   6.72     *
# *............................................................................*
# *Br   25 :n_hits_dp1 : n_hits_dp1/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        542 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   7.53     *
# *............................................................................*
# *Br   26 :n_hits_dp2 : n_hits_dp2/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        540 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   7.55     *
# *............................................................................*
# *Br   27 :hit_detID : hit_detID[n_hits]/I                                    *
# *Entries :     1000 : Total  Size=     125467 bytes  File Size  =      11014 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=  11.34     *
# *............................................................................*
# *Br   28 :hit_elmID : hit_elmID[n_hits]/I                                    *
# *Entries :     1000 : Total  Size=     125467 bytes  File Size  =      38249 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   3.26     *
# *............................................................................*
# *Br   29 :hit_trkID : hit_trkID[n_hits]/I                                    *
# *Entries :     1000 : Total  Size=     125467 bytes  File Size  =       3779 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=  33.05     *
# *............................................................................*
# *Br   30 :hit_driftdis : hit_driftdis[n_hits]/F                              *
# *Entries :     1000 : Total  Size=     125501 bytes  File Size  =      91494 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   1.37     *
# *............................................................................*
# *Br   31 :hit_pos   : hit_pos[n_hits]/F                                      *
# *Entries :     1000 : Total  Size=     125456 bytes  File Size  =      64020 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   1.95     *
# *............................................................................*
# *Br   32 :hit_edep  : hit_edep[n_hits]/F                                     *
# *Entries :     1000 : Total  Size=     125465 bytes  File Size  =       3782 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=  33.02     *
# *............................................................................*
# *Br   33 :hit_truthx : hit_truthx[n_hits]/F                                  *
# *Entries :     1000 : Total  Size=     125483 bytes  File Size  =     113474 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   1.10     *
# *............................................................................*
# *Br   34 :hit_truthy : hit_truthy[n_hits]/F                                  *
# *Entries :     1000 : Total  Size=     125483 bytes  File Size  =     115101 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   1.08     *
# *............................................................................*
# *Br   35 :hit_truthz : hit_truthz[n_hits]/F                                  *
# *Entries :     1000 : Total  Size=     125483 bytes  File Size  =      11373 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=  10.98     *
# *............................................................................*
# *Br   36 :hit_truthpx : hit_truthpx[n_hits]/F                                *
# *Entries :     1000 : Total  Size=     125492 bytes  File Size  =      99147 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   1.26     *
# *............................................................................*
# *Br   37 :hit_truthpy : hit_truthpy[n_hits]/F                                *
# *Entries :     1000 : Total  Size=     125492 bytes  File Size  =      97342 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   1.28     *
# *............................................................................*
# *Br   38 :hit_truthpz : hit_truthpz[n_hits]/F                                *
# *Entries :     1000 : Total  Size=     125492 bytes  File Size  =      70393 *
# *Baskets :        5 : Basket Size=      32000 bytes  Compression=   1.77     *
# *............................................................................*
# *Br   39 :n_truthtracks : n_truthtracks/I                                    *
# *Entries :     1000 : Total  Size=       4599 bytes  File Size  =        137 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  29.80     *
# *............................................................................*
# *Br   40 :truthtrack_charge : truthtrack_charge[n_truthtracks]/I             *
# *Entries :     1000 : Total  Size=       8743 bytes  File Size  =       1400 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.78     *
# *............................................................................*
# *Br   41 :truthtrack_x_st1 : truthtrack_x_st1[n_truthtracks]/F               *
# *Entries :     1000 : Total  Size=       8745 bytes  File Size  =       5320 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.52     *
# *............................................................................*
# *Br   42 :truthtrack_y_st1 : truthtrack_y_st1[n_truthtracks]/F               *
# *Entries :     1000 : Total  Size=       8745 bytes  File Size  =       5359 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.51     *
# *............................................................................*
# *Br   43 :truthtrack_z_st1 : truthtrack_z_st1[n_truthtracks]/F               *
# *Entries :     1000 : Total  Size=       8745 bytes  File Size  =       1740 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.65     *
# *............................................................................*
# *Br   44 :truthtrack_px_st1 : truthtrack_px_st1[n_truthtracks]/F             *
# *Entries :     1000 : Total  Size=       8750 bytes  File Size  =       5291 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.53     *
# *............................................................................*
# *Br   45 :truthtrack_py_st1 : truthtrack_py_st1[n_truthtracks]/F             *
# *Entries :     1000 : Total  Size=       8750 bytes  File Size  =       5350 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.51     *
# *............................................................................*
# *Br   46 :truthtrack_pz_st1 : truthtrack_pz_st1[n_truthtracks]/F             *
# *Entries :     1000 : Total  Size=       8750 bytes  File Size  =       5174 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.56     *
# *............................................................................*
# *Br   47 :truthtrack_x_st3 : truthtrack_x_st3[n_truthtracks]/F               *
# *Entries :     1000 : Total  Size=       8745 bytes  File Size  =       5105 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.59     *
# *............................................................................*
# *Br   48 :truthtrack_y_st3 : truthtrack_y_st3[n_truthtracks]/F               *
# *Entries :     1000 : Total  Size=       8745 bytes  File Size  =       5184 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.56     *
# *............................................................................*
# *Br   49 :truthtrack_z_st3 : truthtrack_z_st3[n_truthtracks]/F               *
# *Entries :     1000 : Total  Size=       8745 bytes  File Size  =       2376 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   3.41     *
# *............................................................................*
# *Br   50 :truthtrack_px_st3 : truthtrack_px_st3[n_truthtracks]/F             *
# *Entries :     1000 : Total  Size=       8750 bytes  File Size  =       5089 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.59     *
# *............................................................................*
# *Br   51 :truthtrack_py_st3 : truthtrack_py_st3[n_truthtracks]/F             *
# *Entries :     1000 : Total  Size=       8750 bytes  File Size  =       5173 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.56     *
# *............................................................................*
# *Br   52 :truthtrack_pz_st3 : truthtrack_pz_st3[n_truthtracks]/F             *
# *Entries :     1000 : Total  Size=       8750 bytes  File Size  =       4995 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.62     *
# *............................................................................*
# *Br   53 :truthtrack_x_vtx : truthtrack_x_vtx[n_truthtracks]/F               *
# *Entries :     1000 : Total  Size=       8745 bytes  File Size  =       5488 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.47     *
# *............................................................................*
# *Br   54 :truthtrack_y_vtx : truthtrack_y_vtx[n_truthtracks]/F               *
# *Entries :     1000 : Total  Size=       8745 bytes  File Size  =       5490 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.47     *
# *............................................................................*
# *Br   55 :truthtrack_z_vtx : truthtrack_z_vtx[n_truthtracks]/F               *
# *Entries :     1000 : Total  Size=       8745 bytes  File Size  =       5466 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.48     *
# *............................................................................*
# *Br   56 :truthtrack_px_vtx : truthtrack_px_vtx[n_truthtracks]/F             *
# *Entries :     1000 : Total  Size=       8750 bytes  File Size  =       5495 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.47     *
# *............................................................................*
# *Br   57 :truthtrack_py_vtx : truthtrack_py_vtx[n_truthtracks]/F             *
# *Entries :     1000 : Total  Size=       8750 bytes  File Size  =       5488 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.47     *
# *............................................................................*
# *Br   58 :truthtrack_pz_vtx : truthtrack_pz_vtx[n_truthtracks]/F             *
# *Entries :     1000 : Total  Size=       8750 bytes  File Size  =       5289 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.53     *
# *............................................................................*
# *Br   59 :truthtrack_rectrack_id : truthtrack_rectrack_id[n_truthtracks]/I   *
# *Entries :     1000 : Total  Size=       8768 bytes  File Size  =       2038 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   3.97     *
# *............................................................................*
# *Br   60 :rec_status : rec_status/I                                          *
# *Entries :     1000 : Total  Size=       4584 bytes  File Size  =        703 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.80     *
# *............................................................................*
# *Br   61 :n_tracks  : n_tracks/I                                             *
# *Entries :     1000 : Total  Size=       4574 bytes  File Size  =        540 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   7.55     *
# *............................................................................*
# *Br   62 :track_charge : track_charge[n_tracks]/I                            *
# *Entries :     1000 : Total  Size=       6326 bytes  File Size  =       1003 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.70     *
# *............................................................................*
# *Br   63 :track_particleID : track_particleID[n_tracks]/I                    *
# *Entries :     1000 : Total  Size=       6346 bytes  File Size  =       1004 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.70     *
# *............................................................................*
# *Br   64 :track_nhits : track_nhits[n_tracks]/I                              *
# *Entries :     1000 : Total  Size=       6321 bytes  File Size  =       1249 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.58     *
# *............................................................................*
# *Br   65 :track_x_target : track_x_target[n_tracks]/F                        *
# *Entries :     1000 : Total  Size=       6343 bytes  File Size  =       2682 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.13     *
# *............................................................................*
# *Br   66 :track_y_target : track_y_target[n_tracks]/F                        *
# *Entries :     1000 : Total  Size=       6343 bytes  File Size  =       2692 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.12     *
# *............................................................................*
# *Br   67 :track_z_target : track_z_target[n_tracks]/F                        *
# *Entries :     1000 : Total  Size=       6343 bytes  File Size  =       1010 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.66     *
# *............................................................................*
# *Br   68 :track_px_target : track_px_target[n_tracks]/F                      *
# *Entries :     1000 : Total  Size=       6348 bytes  File Size  =       2661 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.15     *
# *............................................................................*
# *Br   69 :track_py_target : track_py_target[n_tracks]/F                      *
# *Entries :     1000 : Total  Size=       6348 bytes  File Size  =       2680 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.13     *
# *............................................................................*
# *Br   70 :track_pz_target : track_pz_target[n_tracks]/F                      *
# *Entries :     1000 : Total  Size=       6348 bytes  File Size  =       2571 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.22     *
# *............................................................................*
# *Br   71 :track_x_st1 : track_x_st1[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2668 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.14     *
# *............................................................................*
# *Br   72 :track_y_st1 : track_y_st1[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2677 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.14     *
# *............................................................................*
# *Br   73 :track_z_st1 : track_z_st1[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2087 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.74     *
# *............................................................................*
# *Br   74 :track_px_st1 : track_px_st1[n_tracks]/F                            *
# *Entries :     1000 : Total  Size=       6333 bytes  File Size  =       2637 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.17     *
# *............................................................................*
# *Br   75 :track_py_st1 : track_py_st1[n_tracks]/F                            *
# *Entries :     1000 : Total  Size=       6333 bytes  File Size  =       2680 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.13     *
# *............................................................................*
# *Br   76 :track_pz_st1 : track_pz_st1[n_tracks]/F                            *
# *Entries :     1000 : Total  Size=       6333 bytes  File Size  =       2584 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.21     *
# *............................................................................*
# *Br   77 :track_x_st3 : track_x_st3[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2621 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.18     *
# *............................................................................*
# *Br   78 :track_y_st3 : track_y_st3[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2676 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.14     *
# *............................................................................*
# *Br   79 :track_z_st3 : track_z_st3[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2104 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.72     *
# *............................................................................*
# *Br   80 :track_px_st3 : track_px_st3[n_tracks]/F                            *
# *Entries :     1000 : Total  Size=       6333 bytes  File Size  =       2624 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.18     *
# *............................................................................*
# *Br   81 :track_py_st3 : track_py_st3[n_tracks]/F                            *
# *Entries :     1000 : Total  Size=       6333 bytes  File Size  =       2683 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.13     *
# *............................................................................*
# *Br   82 :track_pz_st3 : track_pz_st3[n_tracks]/F                            *
# *Entries :     1000 : Total  Size=       6333 bytes  File Size  =       2580 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.22     *
# *............................................................................*
# *Br   83 :track_x_vtx : track_x_vtx[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2713 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.11     *
# *............................................................................*
# *Br   84 :track_y_vtx : track_y_vtx[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2717 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.10     *
# *............................................................................*
# *Br   85 :track_z_vtx : track_z_vtx[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       1944 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.94     *
# *............................................................................*
# *Br   86 :track_px_vtx : track_px_vtx[n_tracks]/F                            *
# *Entries :     1000 : Total  Size=       6333 bytes  File Size  =       2687 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.13     *
# *............................................................................*
# *Br   87 :track_py_vtx : track_py_vtx[n_tracks]/F                            *
# *Entries :     1000 : Total  Size=       6333 bytes  File Size  =       2691 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.12     *
# *............................................................................*
# *Br   88 :track_pz_vtx : track_pz_vtx[n_tracks]/F                            *
# *Entries :     1000 : Total  Size=       6333 bytes  File Size  =       2590 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.21     *
# *............................................................................*
# *Br   89 :track_x_CAL : track_x_CAL[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2614 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.19     *
# *............................................................................*
# *Br   90 :track_y_CAL : track_y_CAL[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2684 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.13     *
# *............................................................................*
# *Br   91 :track_chisq : track_chisq[n_tracks]/F                              *
# *Entries :     1000 : Total  Size=       6328 bytes  File Size  =       2685 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.13     *
# *............................................................................*
# *Br   92 :track_prob : track_prob[n_tracks]/F                                *
# *Entries :     1000 : Total  Size=       6323 bytes  File Size  =       1039 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.50     *
# *............................................................................*
# *Br   93 :track_quality : track_quality[n_tracks]/F                          *
# *Entries :     1000 : Total  Size=       6338 bytes  File Size  =       2075 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.76     *
# *............................................................................*
# *Br   94 :track_isValid : track_isValid[n_tracks]/I                          *
# *Entries :     1000 : Total  Size=       6331 bytes  File Size  =       1182 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.84     *
# *............................................................................*
# *Br   95 :track_matched : track_matched[n_tracks]/I                          *
# *Entries :     1000 : Total  Size=       6331 bytes  File Size  =       1005 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.69     *
# *............................................................................*
# *Br   96 :track_nhits_st1 : track_nhits_st1[n_tracks]/I                      *
# *Entries :     1000 : Total  Size=       6341 bytes  File Size  =       1249 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.58     *
# *............................................................................*
# *Br   97 :track_nhits_st2 : track_nhits_st2[n_tracks]/I                      *
# *Entries :     1000 : Total  Size=       6341 bytes  File Size  =       1001 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.71     *
# *............................................................................*
# *Br   98 :track_nhits_st3 : track_nhits_st3[n_tracks]/I                      *
# *Entries :     1000 : Total  Size=       6341 bytes  File Size  =       1001 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.71     *
# *............................................................................*
# *Br   99 :n_st3tracklets : n_st3tracklets/I                                  *
# *Entries :     1000 : Total  Size=       4604 bytes  File Size  =        133 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  30.70     *
# *............................................................................*
# *Br  100 :st3tracklet_charge : st3tracklet_charge[n_st3tracklets]/I          *
# *Entries :     1000 : Total  Size=       4752 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  101 :st3tracklet_nhits : st3tracklet_nhits[n_st3tracklets]/I            *
# *Entries :     1000 : Total  Size=       4747 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  102 :st3tracklet_x_target : st3tracklet_x_target[n_st3tracklets]/F      *
# *Entries :     1000 : Total  Size=       4769 bytes  File Size  =        150 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.31     *
# *............................................................................*
# *Br  103 :st3tracklet_y_target : st3tracklet_y_target[n_st3tracklets]/F      *
# *Entries :     1000 : Total  Size=       4769 bytes  File Size  =        150 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.31     *
# *............................................................................*
# *Br  104 :st3tracklet_z_target : st3tracklet_z_target[n_st3tracklets]/F      *
# *Entries :     1000 : Total  Size=       4769 bytes  File Size  =        150 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.31     *
# *............................................................................*
# *Br  105 :st3tracklet_px_target : st3tracklet_px_target[n_st3tracklets]/F    *
# *Entries :     1000 : Total  Size=       4774 bytes  File Size  =        151 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.14     *
# *............................................................................*
# *Br  106 :st3tracklet_py_target : st3tracklet_py_target[n_st3tracklets]/F    *
# *Entries :     1000 : Total  Size=       4774 bytes  File Size  =        151 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.14     *
# *............................................................................*
# *Br  107 :st3tracklet_pz_target : st3tracklet_pz_target[n_st3tracklets]/F    *
# *Entries :     1000 : Total  Size=       4774 bytes  File Size  =        151 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.14     *
# *............................................................................*
# *Br  108 :st3tracklet_x_st1 : st3tracklet_x_st1[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  109 :st3tracklet_y_st1 : st3tracklet_y_st1[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  110 :st3tracklet_z_st1 : st3tracklet_z_st1[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  111 :st3tracklet_px_st1 : st3tracklet_px_st1[n_st3tracklets]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  112 :st3tracklet_py_st1 : st3tracklet_py_st1[n_st3tracklets]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  113 :st3tracklet_pz_st1 : st3tracklet_pz_st1[n_st3tracklets]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  114 :st3tracklet_x_st3 : st3tracklet_x_st3[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  115 :st3tracklet_y_st3 : st3tracklet_y_st3[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  116 :st3tracklet_z_st3 : st3tracklet_z_st3[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  117 :st3tracklet_px_st3 : st3tracklet_px_st3[n_st3tracklets]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  118 :st3tracklet_py_st3 : st3tracklet_py_st3[n_st3tracklets]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  119 :st3tracklet_pz_st3 : st3tracklet_pz_st3[n_st3tracklets]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  120 :st3tracklet_x_vtx : st3tracklet_x_vtx[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  121 :st3tracklet_y_vtx : st3tracklet_y_vtx[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  122 :st3tracklet_z_vtx : st3tracklet_z_vtx[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  123 :st3tracklet_px_vtx : st3tracklet_px_vtx[n_st3tracklets]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  124 :st3tracklet_py_vtx : st3tracklet_py_vtx[n_st3tracklets]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  125 :st3tracklet_pz_vtx : st3tracklet_pz_vtx[n_st3tracklets]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  126 :st3tracklet_m : st3tracklet_m[n_st3tracklets]/F                    *
# *Entries :     1000 : Total  Size=       4734 bytes  File Size  =        143 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  28.60     *
# *............................................................................*
# *Br  127 :st3tracklet_x_CAL : st3tracklet_x_CAL[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  128 :st3tracklet_y_CAL : st3tracklet_y_CAL[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  129 :st3tracklet_chisq : st3tracklet_chisq[n_st3tracklets]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  130 :st3tracklet_prob : st3tracklet_prob[n_st3tracklets]/F              *
# *Entries :     1000 : Total  Size=       4749 bytes  File Size  =        146 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  28.03     *
# *............................................................................*
# *Br  131 :st3tracklet_quality : st3tracklet_quality[n_st3tracklets]/F        *
# *Entries :     1000 : Total  Size=       4764 bytes  File Size  =        149 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.49     *
# *............................................................................*
# *Br  132 :st3tracklet_isValid : st3tracklet_isValid[n_st3tracklets]/I        *
# *Entries :     1000 : Total  Size=       4757 bytes  File Size  =        149 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.49     *
# *............................................................................*
# *Br  133 :st3tracklet_nhits_st1 : st3tracklet_nhits_st1[n_st3tracklets]/I    *
# *Entries :     1000 : Total  Size=       4767 bytes  File Size  =        151 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.14     *
# *............................................................................*
# *Br  134 :st3tracklet_nhits_st2 : st3tracklet_nhits_st2[n_st3tracklets]/I    *
# *Entries :     1000 : Total  Size=       4767 bytes  File Size  =        151 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.14     *
# *............................................................................*
# *Br  135 :st3tracklet_nhits_st3 : st3tracklet_nhits_st3[n_st3tracklets]/I    *
# *Entries :     1000 : Total  Size=       4767 bytes  File Size  =        151 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.14     *
# *............................................................................*
# *Br  136 :n_truthdimuons : n_truthdimuons/I                                  *
# *Entries :     1000 : Total  Size=       4604 bytes  File Size  =        133 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  30.70     *
# *............................................................................*
# *Br  137 :truthdimuon_mass : truthdimuon_mass[n_truthdimuons]/F              *
# *Entries :     1000 : Total  Size=       4749 bytes  File Size  =        146 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  28.03     *
# *............................................................................*
# *Br  138 :truthdimuon_x_vtx : truthdimuon_x_vtx[n_truthdimuons]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  139 :truthdimuon_y_vtx : truthdimuon_y_vtx[n_truthdimuons]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  140 :truthdimuon_z_vtx : truthdimuon_z_vtx[n_truthdimuons]/F            *
# *Entries :     1000 : Total  Size=       4754 bytes  File Size  =        147 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.85     *
# *............................................................................*
# *Br  141 :truthdimuon_px : truthdimuon_px[n_truthdimuons]/F                  *
# *Entries :     1000 : Total  Size=       4739 bytes  File Size  =        144 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  28.41     *
# *............................................................................*
# *Br  142 :truthdimuon_py : truthdimuon_py[n_truthdimuons]/F                  *
# *Entries :     1000 : Total  Size=       4739 bytes  File Size  =        144 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  28.41     *
# *............................................................................*
# *Br  143 :truthdimuon_pz : truthdimuon_pz[n_truthdimuons]/F                  *
# *Entries :     1000 : Total  Size=       4739 bytes  File Size  =        144 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  28.41     *
# *............................................................................*
# *Br  144 :truthdimuon_pmom_x : truthdimuon_pmom_x[n_truthdimuons]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  145 :truthdimuon_pmom_y : truthdimuon_pmom_y[n_truthdimuons]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  146 :truthdimuon_pmom_z : truthdimuon_pmom_z[n_truthdimuons]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  147 :truthdimuon_nmom_x : truthdimuon_nmom_x[n_truthdimuons]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  148 :truthdimuon_nmom_y : truthdimuon_nmom_y[n_truthdimuons]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  149 :truthdimuon_nmom_z : truthdimuon_nmom_z[n_truthdimuons]/F          *
# *Entries :     1000 : Total  Size=       4759 bytes  File Size  =        148 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  27.67     *
# *............................................................................*
# *Br  150 :truthdimuon_recoed : truthdimuon_recoed[n_truthdimuons]/I          *
# *Entries :     1000 : Total  Size=       4752 bytes  File Size  =        148 *
# ...
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.53     *
# *............................................................................*
# *Br  201 :gy_st1    : gy_st1[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       5329 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.52     *
# *............................................................................*
# *Br  202 :gz_st1    : gz_st1[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       1714 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.72     *
# *............................................................................*
# *Br  203 :gpx_st1   : gpx_st1[n_primaries]/F                                 *
# *Entries :     1000 : Total  Size=       8692 bytes  File Size  =       5253 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.54     *
# *............................................................................*
# *Br  204 :gpy_st1   : gpy_st1[n_primaries]/F                                 *
# *Entries :     1000 : Total  Size=       8692 bytes  File Size  =       5330 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.52     *
# *............................................................................*
# *Br  205 :gpz_st1   : gpz_st1[n_primaries]/F                                 *
# *Entries :     1000 : Total  Size=       8692 bytes  File Size  =       5152 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.57     *
# *............................................................................*
# *Br  206 :gx_st2    : gx_st2[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       5078 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.59     *
# *............................................................................*
# *Br  207 :gy_st2    : gy_st2[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       5145 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.57     *
# *............................................................................*
# *Br  208 :gz_st2    : gz_st2[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       1844 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.38     *
# *............................................................................*
# *Br  209 :gpx_st2   : gpx_st2[n_primaries]/F                                 *
# *Entries :     1000 : Total  Size=       8692 bytes  File Size  =       5051 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.60     *
# *............................................................................*
# *Br  210 :gpy_st2   : gpy_st2[n_primaries]/F                                 *
# *Entries :     1000 : Total  Size=       8692 bytes  File Size  =       5139 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.57     *
# *............................................................................*
# *Br  211 :gpz_st2   : gpz_st2[n_primaries]/F                                 *
# *Entries :     1000 : Total  Size=       8692 bytes  File Size  =       4970 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.63     *
# *............................................................................*
# *Br  212 :gx_st3    : gx_st3[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3969 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.04     *
# *............................................................................*
# *Br  213 :gy_st3    : gy_st3[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3991 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.03     *
# *............................................................................*
# *Br  214 :gz_st3    : gz_st3[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       1990 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.06     *
# *............................................................................*
# *Br  215 :gpx_st3   : gpx_st3[n_primaries]/F                                 *
# *Entries :     1000 : Total  Size=       8692 bytes  File Size  =       3952 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.05     *
# *............................................................................*
# *Br  216 :gpy_st3   : gpy_st3[n_primaries]/F                                 *
# *Entries :     1000 : Total  Size=       8692 bytes  File Size  =       3978 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.03     *
# *............................................................................*
# *Br  217 :gpz_st3   : gpz_st3[n_primaries]/F                                 *
# *Entries :     1000 : Total  Size=       8692 bytes  File Size  =       3891 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.08     *
# *............................................................................*
# *Br  218 :gx_h1     : gx_h1[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       5366 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.51     *
# *............................................................................*
# *Br  219 :gy_h1     : gy_h1[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       5397 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.50     *
# *............................................................................*
# *Br  220 :gz_h1     : gz_h1[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       2121 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   3.81     *
# *............................................................................*
# *Br  221 :gpx_h1    : gpx_h1[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       5310 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.52     *
# *............................................................................*
# *Br  222 :gpy_h1    : gpy_h1[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       5383 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.50     *
# *............................................................................*
# *Br  223 :gpz_h1    : gpz_h1[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       5219 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   1.55     *
# *............................................................................*
# *Br  224 :gx_h2     : gx_h2[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       3630 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.23     *
# *............................................................................*
# *Br  225 :gy_h2     : gy_h2[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       3634 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.22     *
# *............................................................................*
# *Br  226 :gz_h2     : gz_h2[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       1996 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.05     *
# *............................................................................*
# *Br  227 :gpx_h2    : gpx_h2[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3626 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.23     *
# *............................................................................*
# *Br  228 :gpy_h2    : gpy_h2[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3633 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.22     *
# *............................................................................*
# *Br  229 :gpz_h2    : gpz_h2[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3581 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.26     *
# *............................................................................*
# *Br  230 :gx_h3     : gx_h3[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       3581 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.26     *
# *............................................................................*
# *Br  231 :gy_h3     : gy_h3[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       3575 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.26     *
# *............................................................................*
# *Br  232 :gz_h3     : gz_h3[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       1994 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.05     *
# *............................................................................*
# *Br  233 :gpx_h3    : gpx_h3[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3585 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.25     *
# *............................................................................*
# *Br  234 :gpy_h3    : gpy_h3[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3581 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.26     *
# *............................................................................*
# *Br  235 :gpz_h3    : gpz_h3[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3514 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.30     *
# *............................................................................*
# *Br  236 :gx_h4     : gx_h4[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       3584 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.26     *
# *............................................................................*
# *Br  237 :gy_h4     : gy_h4[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       3568 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.27     *
# *............................................................................*
# *Br  238 :gz_h4     : gz_h4[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       2008 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   4.02     *
# *............................................................................*
# *Br  239 :gpx_h4    : gpx_h4[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3587 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.25     *
# *............................................................................*
# *Br  240 :gpy_h4    : gpy_h4[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3595 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.25     *
# *............................................................................*
# *Br  241 :gpz_h4    : gpz_h4[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       3522 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   2.30     *
# *............................................................................*
# *Br  242 :gx_p1     : gx_p1[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       1385 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.84     *
# *............................................................................*
# *Br  243 :gy_p1     : gy_p1[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       1385 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.84     *
# *............................................................................*
# *Br  244 :gz_p1     : gz_p1[n_primaries]/F                                   *
# *Entries :     1000 : Total  Size=       8682 bytes  File Size  =       1385 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.84     *
# *............................................................................*
# *Br  245 :gpx_p1    : gpx_p1[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       1384 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.84     *
# *............................................................................*
# *Br  246 :gpy_p1    : gpy_p1[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       1384 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.84     *
# *............................................................................*
# *Br  247 :gpz_p1    : gpz_p1[n_primaries]/F                                  *
# *Entries :     1000 : Total  Size=       8687 bytes  File Size  =       1384 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=   5.84     *
# *............................................................................*
# *Br  248 :fpga_trigger : fpga_trigger[5]/O                                   *
# *Entries :     1000 : Total  Size=       5594 bytes  File Size  =        483 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  10.52     *
# *............................................................................*
# *Br  249 :nim_trigger : nim_trigger[5]/O                                     *
# *Entries :     1000 : Total  Size=       5589 bytes  File Size  =        134 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  37.91     *
# *............................................................................*
# *Br  250 :weight    : weight/F                                               *
# *Entries :     1000 : Total  Size=       4564 bytes  File Size  =        133 *
# *Baskets :        1 : Basket Size=      32000 bytes  Compression=  30.64     *
# *............................................................................*

# %%
files=[]
#for i in range(9):
#    file=ROOT.TFile(f"reco_displaced_mu+_1930_-200_{i}.root","READ")
#    files.append(file)
files=[ROOT.TFile("target_standard_mu-_1930_0.root","READ")]

# %%
import matplotlib.pyplot as plt

# %%
zs=[]
xs=[]
ys=[]
pzs=[]
pzs_st1=[]
pxs=[]
pxs_st1=[]
pys=[]
nhits_d3=[]
pos_hits_st3=[]
n_dimuons=[]
dimuon_pz=[]
truthdimuon_pz=[]
dimuon_mass=[]
truthdimuon_mass=[]
count=0
for file in files:
    print(file)
    events=file.Events
    for entry in events:
        zs.append(entry.truthtrack_z_vtx[0])
        ys.append(entry.truthtrack_y_vtx[0])
        xs.append(entry.truthtrack_x_vtx[0])
        pzs.append(entry.truthtrack_pz_vtx[0])
        pzs_st1.append(entry.truthtrack_pz_st1[0])
        pys.append(entry.truthtrack_py_vtx[0])
        pxs.append(entry.truthtrack_px_vtx[0])
        pxs_st1.append(entry.truthtrack_px_st1[0])
        nhits_d3.append(entry.n_hits_d3p+entry.n_hits_d3m)
        n_dimuons.append(entry.n_dimuons)

        #for i in range(entry.n_truthdimuons):
        #    truthdimuon_mass.append(entry.truthdimuon_mass[i])
        for i in range(entry.n_dimuons):
            if entry.dimuon_matched[i]==1 or 1==1 :
                #truthdimuon_mass.append(entry.truthdimuon_mass[0])
                dimuon_mass.append(entry.dimuon_mass[i])
                #truthdimuon_pz.append(entry.truthdimuon_pz[0])
                dimuon_pz.append(entry.dimuon_pz[i])
                #print("!")
                break
            #print("?")
        for i in range(entry.n_dimuons):
            if (entry.dimuon_matched[i]==1 or 1==1)and entry.n_truthdimuons>0 and entry.truthdimuon_z_vtx[0]<0 :
                count=count+1
                break
                
        for i in range(entry.n_hits):
            if entry.hit_detID[i]<=30 and entry.hit_detID[i]>=25 :
                pos_hits_st3.append(entry.hit_pos[i])
# Out:
# Name: target_standard_mu-_1930_0.root Title:

# %%
print(len([x for x in nhits_d3 if x>=8]))
print(len(nhits_d3))
# Out:
# 706
# 10000

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(pzs, bins=30, edgecolor='black')
ax.set_xlabel("Pz")
ax.set_ylabel("Counts")
fig.savefig("Pz.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(pxs, bins=30, edgecolor='black')
ax.set_xlabel("Px")
ax.set_ylabel("Counts")
fig.savefig("Px.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(pys, bins=30, edgecolor='black')
ax.set_xlabel("Py")
ax.set_ylabel("Counts")
fig.savefig("Py.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(zs, bins=30, edgecolor='black')
ax.set_xlabel("z")
ax.set_ylabel("Counts")
fig.savefig("z.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(xs, bins=30, edgecolor='black')
ax.set_xlabel("x")
ax.set_ylabel("Counts")
fig.savefig("x.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(ys, bins=30, edgecolor='black')
ax.set_xlabel("y")
ax.set_ylabel("Counts")
fig.savefig("y.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(nhits_d3, bins=13,range=(0,13), edgecolor='black')
ax.set_xlabel("nhits_d3")
ax.set_ylabel("Counts")
fig.savefig("nhits_d3.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(pos_hits_st3, bins=30, edgecolor='black')
ax.set_xlabel("pos_hits_st3")
ax.set_ylabel("Counts")
fig.savefig("pos_hits_st3.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(n_dimuons, bins=4, range=(0,4),edgecolor='black')
ax.set_xlabel("n_dimuons")
ax.set_ylabel("Counts")
fig.savefig("n_dimuons.pdf")

# %%
eff=sum(n_dimuons)/len(n_dimuons)

# %%
eff
# Out:
# 0.029222222222222222

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(pzs)
# Out:
# (array([4.360e+03, 2.298e+03, 1.228e+03, 6.490e+02, 2.600e+02, 1.250e+02,
#         5.500e+01, 1.900e+01, 4.000e+00, 2.000e+00]),
#  array([25.00316429, 29.894631  , 34.78609772, 39.67756443, 44.56903114,
#         49.46049786, 54.35196457, 59.24343128, 64.13489799, 69.02636471,
#         73.91783142]),
#  <BarContainer object of 10 artists>)

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(pzs_st1, bins=30, edgecolor='black')
ax.set_xlabel("Pz_st1")
ax.set_ylabel("Counts")
fig.savefig("Pz_st1.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(pxs_st1, bins=30, edgecolor='black')
ax.set_xlabel("Px_st1")
ax.set_ylabel("Counts")
fig.savefig("Px_st1.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(dimuon_mass, bins=30, range=(0,7),edgecolor='black')
ax.set_xlabel("dimuon_mass")
ax.set_ylabel("Counts")
fig.savefig("dimuon_mass.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(truthdimuon_mass, bins=10000, range=(3.05,3.2),edgecolor='black')
ax.set_xlabel("truthdimuon_mass")
ax.set_ylabel("Counts")
fig.savefig("truthdimuon_mass.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist([a-b for a,b in zip(dimuon_mass,truthdimuon_mass)], bins=100, edgecolor='black')
ax.set_xlabel("truthdimuon_mass")
ax.set_ylabel("Counts")
fig.savefig("truthdimuon_mass.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist([a-b for a,b in zip(dimuon_pz,truthdimuon_pz)], bins=100, edgecolor='black')
ax.set_xlabel("pz diff")
ax.set_ylabel("Counts")
fig.savefig("truthdimuon_mass.pdf")

# %%
fig=plt.figure(dpi=100)
ax=fig.add_subplot()
ax.hist(dimuon_pz, bins=100, edgecolor='black')
ax.set_xlabel("truthdimuon_mass")
ax.set_ylabel("Counts")
fig.savefig("truthdimuon_mass.pdf")

# %%
c=[a-b for a,b in zip(dimuon_pz,truthdimuon_pz)]
c=truthdimuon_pz

# %%
for i in range(len(c)):
    if not ( c[i]>-200 and c[i]<200 ):
        print(c[i])
